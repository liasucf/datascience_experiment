# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
#pour l'entraînement automatique:
from supervised.automl import AutoML

# %%
data =pd.read_csv("../data/raw/mars-2014-complete.csv" ,encoding='latin-1', sep=";")

# %%
data.columns
# Out:
# Index(['lib_mrq', 'lib_mod_doss', 'lib_mod', 'dscom', 'cnit', 'tvv', 'cod_cbr',
#        'hybride', 'puiss_admin_98', 'puiss_max', 'typ_boite_nb_rapp',
#        'conso_urb', 'conso_exurb', 'conso_mixte', 'co2', 'co_typ_1', 'hc',
#        'nox', 'hcnox', 'ptcl', 'masse_ordma_min', 'masse_ordma_max',
#        'champ_v9', 'date_maj', 'Carrosserie', 'gamme', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29'],
#       dtype='object')

# %%
data = data.drop(columns=['date_maj','Unnamed: 26', 'hc', 
       'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'hcnox', 'date_maj' ])

# %%
data = data[data['co2'].isna()==False]

# %%
y = data['co2'].values
X = data.drop(columns=['co2'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
automl = AutoML(total_time_limit=5*60,mode='Explain',random_state=42,ml_task='regression')
#fit models
automl.fit(X_train,y_train)
#predictions
predictions = automl.predict(X_test)
#generate html report
automl.report()
# Out:
# Linear algorithm was disabled.
# AutoML directory: AutoML_1
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Baseline', 'Decision Tree', 'Random Forest', 'Xgboost', 'Neural Network']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'ensemble']
# * Step simple_algorithms will try to check up to 2 models
# 1_Baseline rmse 34.033774 trained in 0.3 seconds
# 2_DecisionTree rmse 6.513054 trained in 15.56 seconds
# * Step default_algorithms will try to check up to 3 models
# 3_Default_Xgboost rmse 1.029347 trained in 67.39 seconds
# 4_Default_NeuralNetwork rmse 10.161166 trained in 12.74 seconds
# 5_Default_RandomForest rmse 5.568396 trained in 20.89 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 1.029347 trained in 0.23 seconds
# AutoML fit time: 130.24 seconds
# AutoML best model: 3_Default_Xgboost
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#
# .styled-table {
# ...
